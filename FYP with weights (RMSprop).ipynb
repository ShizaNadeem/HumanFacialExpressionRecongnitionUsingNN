# %% [markdown]
# **Import libraries**

# %%
import numpy as np
import cv2
import os
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import itertools
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.models import Model, Sequential
from keras.optimizers import Adam, RMSprop
from keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

init_notebook_mode(connected=True)

# Ensure reproducibility
np.random.seed(123)
tf.random.set_seed(123)
# Out:
# 2024-05-12 16:23:05.783482: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-12 16:23:05.783595: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-12 16:23:05.899210: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # **Load Data and Plot Samples**

# %%
TRAIN_DIR = ('/kaggle/input/facial-recognition-dataset/Training/Training/')
TEST_DIR = ('/kaggle/input/facial-recognition-dataset/Testing/Testing/')

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

def load_data(dir_path, IMG_SIZE):
    X = []
    y = []
    labels = dict()
    i = 0
    
    for path in tqdm(sorted(os.listdir(dir_path))):
        if not path.startswith('.'):
            labels[i] = path
            for file in os.listdir(os.path.join(dir_path, path)):
                if not file.startswith('.'):
                    img_path = os.path.join(dir_path, path, file)
                    img = cv2.imread(img_path)
                    if img is not None:
                        img = img.astype('float32') / 255
                        resized = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
                        X.append(resized)
                        y.append(i)
                    else:
                        print(f"Error loading image: {img_path}")
            i += 1
    
    return np.array(X), np.array(y), labels

# Usage example:
TRAIN_DIR = ('/kaggle/input/facial-recognition-dataset/Training/Training/')
IMG_SIZE = (48, 48)  # Example image size
X_train, y_train, train_labels = load_data(TRAIN_DIR, IMG_SIZE)
# Out:
# 100%|██████████| 6/6 [02:11<00:00, 21.89s/it]

# %%
train_labels
# Out:
# {0: 'Angry', 1: 'Fear', 2: 'Happy', 3: 'Neutral', 4: 'Sad', 5: 'Suprise'}

# %%
X_test, y_test, test_labels = load_data(TEST_DIR,IMG_SIZE)
# Out:
# 100%|██████████| 6/6 [00:23<00:00,  3.99s/it]

# %%
def plot_samples(X, y, labels_dict, n=50):
   
    for index in range(len(labels_dict)):
        imgs = X[np.argwhere(y == index)][:n]
        j = 10
        i = int(n/j)

        plt.figure(figsize=(10,3))
        c = 1
        for img in imgs:
            plt.subplot(i,j,c)
            plt.imshow(img[0])

            plt.xticks([])
            plt.yticks([])
            c += 1
        plt.suptitle(labels_dict[index])
        plt.show()

# %%
plot_samples(X_train, y_train, train_labels, 10)

# %%
from keras.utils import to_categorical

Y_train = to_categorical(y_train, num_classes=6)
print(Y_train.shape)
# Out:
# (28273, 6)

# %%
Y_test = to_categorical(y_test, num_classes=6)
Y_test.shape
# Out:
# (7067, 6)

# %% [markdown]
# # Model with weights

# %%
from keras.applications.vgg16 import VGG16

# Path to the ImageNet weights file
weights_path = '/kaggle/input/imagenet/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5'

base_model = VGG16(
    weights=weights_path,
    include_top=False,
    input_shape=IMG_SIZE + (3,)
)

base_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 48, 48, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 48, 48, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 1, 1, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
NUM_CLASSES = 6

model = Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(1000, activation="relu"))
model.add(Dropout(0.4))
model.add(Dense(NUM_CLASSES, activation="softmax"))

# %%
def deep_model(model, X_train, Y_train, X_val, Y_val, epochs, batch_size):
    # Check input shapes
    print("X_train shape:", X_train.shape)
    print("Y_train shape:", Y_train.shape)
    print("X_val shape:", X_val.shape)
    print("Y_val shape:", Y_val.shape)
    
    # Compile the model
    model.compile(
        loss='binary_crossentropy',
        optimizer=RMSprop(learning_rate=1e-4),
        metrics=['accuracy']
    )
    
    # Fit the model
    history = model.fit(
        X_train,
        Y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_val, Y_val),  # Use X_val, Y_val for validation
        verbose=1
    )
    
    return history

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

def plot_metrics(history):
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

# %%
history = deep_model(model, X_train, Y_train, X_test, Y_test, epochs=48, batch_size=32)
# Out:
# X_train shape: (28273, 48, 48, 3)
# Y_train shape: (28273, 6)
# X_val shape: (7067, 48, 48, 3)
# Y_val shape: (7067, 6)
# Epoch 1/48
#   2/884 ━━━━━━━━━━━━━━━━━━━━ 46s 53ms/step - accuracy: 0.2422 - loss: 0.6562
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715531255.767214     116 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1715531255.790941     116 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3734 - loss: 0.4026
# W0000 00:00:1715531291.884244     116 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1715531293.198216     119 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 56s 48ms/step - accuracy: 0.3735 - loss: 0.4025 - val_accuracy: 0.5618 - val_loss: 0.3039
# Epoch 2/48
#   5/884 ━━━━━━━━━━━━━━━━━━━━ 28s 33ms/step - accuracy: 0.6032 - loss: 0.2892
# W0000 00:00:1715531298.387758     119 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 32s 36ms/step - accuracy: 0.5704 - loss: 0.3016 - val_accuracy: 0.5922 - val_loss: 0.2887
# Epoch 3/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.6329 - loss: 0.2674 - val_accuracy: 0.6005 - val_loss: 0.2883
# Epoch 4/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.6892 - loss: 0.2370 - val_accuracy: 0.6121 - val_loss: 0.2890
# Epoch 5/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.7353 - loss: 0.2077 - val_accuracy: 0.5959 - val_loss: 0.3077
# Epoch 6/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.7822 - loss: 0.1784 - val_accuracy: 0.6133 - val_loss: 0.3141
# Epoch 7/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.8099 - loss: 0.1553 - val_accuracy: 0.6267 - val_loss: 0.3138
# Epoch 8/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.8449 - loss: 0.1319 - val_accuracy: 0.6314 - val_loss: 0.3319
# Epoch 9/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.8623 - loss: 0.1170 - val_accuracy: 0.6353 - val_loss: 0.3536
# Epoch 10/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.8806 - loss: 0.1009 - val_accuracy: 0.6320 - val_loss: 0.3543
# Epoch 11/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.8918 - loss: 0.0916 - val_accuracy: 0.6046 - val_loss: 0.4108
# Epoch 12/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9070 - loss: 0.0798 - val_accuracy: 0.6055 - val_loss: 0.4231
# Epoch 13/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9174 - loss: 0.0712 - val_accuracy: 0.6345 - val_loss: 0.3983
# Epoch 14/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9282 - loss: 0.0626 - val_accuracy: 0.6311 - val_loss: 0.4425
# Epoch 15/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9341 - loss: 0.0573 - val_accuracy: 0.6141 - val_loss: 0.4779
# Epoch 16/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9398 - loss: 0.0527 - val_accuracy: 0.6172 - val_loss: 0.4565
# Epoch 17/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9457 - loss: 0.0480 - val_accuracy: 0.6154 - val_loss: 0.4943
# Epoch 18/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9531 - loss: 0.0449 - val_accuracy: 0.6339 - val_loss: 0.5850
# Epoch 19/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9547 - loss: 0.0409 - val_accuracy: 0.6485 - val_loss: 0.5260
# Epoch 20/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9602 - loss: 0.0380 - val_accuracy: 0.6295 - val_loss: 0.5369
# Epoch 21/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9628 - loss: 0.0366 - val_accuracy: 0.6212 - val_loss: 0.5841
# Epoch 22/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9648 - loss: 0.0327 - val_accuracy: 0.6380 - val_loss: 0.5607
# Epoch 23/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9679 - loss: 0.0311 - val_accuracy: 0.6291 - val_loss: 0.5783
# Epoch 24/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9713 - loss: 0.0299 - val_accuracy: 0.6311 - val_loss: 0.5421
# Epoch 25/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 41s 37ms/step - accuracy: 0.9685 - loss: 0.0294 - val_accuracy: 0.6376 - val_loss: 0.5698
# Epoch 26/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9723 - loss: 0.0270 - val_accuracy: 0.6359 - val_loss: 0.5956
# Epoch 27/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9730 - loss: 0.0275 - val_accuracy: 0.6264 - val_loss: 0.6577
# Epoch 28/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9737 - loss: 0.0262 - val_accuracy: 0.6417 - val_loss: 0.6407
# Epoch 29/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9771 - loss: 0.0247 - val_accuracy: 0.6363 - val_loss: 0.6447
# Epoch 30/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9772 - loss: 0.0240 - val_accuracy: 0.6372 - val_loss: 0.6723
# Epoch 31/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9796 - loss: 0.0220 - val_accuracy: 0.6178 - val_loss: 0.6352
# Epoch 32/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9784 - loss: 0.0223 - val_accuracy: 0.6380 - val_loss: 0.7837
# Epoch 33/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9785 - loss: 0.0222 - val_accuracy: 0.6346 - val_loss: 0.6819
# Epoch 34/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9806 - loss: 0.0202 - val_accuracy: 0.6447 - val_loss: 0.7038
# Epoch 35/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9807 - loss: 0.0200 - val_accuracy: 0.6295 - val_loss: 0.7731
# Epoch 36/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9827 - loss: 0.0192 - val_accuracy: 0.6336 - val_loss: 0.6930
# Epoch 37/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9818 - loss: 0.0196 - val_accuracy: 0.6461 - val_loss: 0.8548
# Epoch 38/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9820 - loss: 0.0211 - val_accuracy: 0.6341 - val_loss: 0.9700
# Epoch 39/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9810 - loss: 0.0219 - val_accuracy: 0.6472 - val_loss: 0.6570
# Epoch 40/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9824 - loss: 0.0178 - val_accuracy: 0.6464 - val_loss: 0.7666
# Epoch 41/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9842 - loss: 0.0175 - val_accuracy: 0.6433 - val_loss: 0.8638
# Epoch 42/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9823 - loss: 0.0210 - val_accuracy: 0.6450 - val_loss: 0.6169
# Epoch 43/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9852 - loss: 0.0167 - val_accuracy: 0.6479 - val_loss: 0.7872
# Epoch 44/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9853 - loss: 0.0167 - val_accuracy: 0.6434 - val_loss: 0.8408
# Epoch 45/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9852 - loss: 0.0170 - val_accuracy: 0.6404 - val_loss: 0.7572
# Epoch 46/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9845 - loss: 0.0190 - val_accuracy: 0.6213 - val_loss: 0.7125
# Epoch 47/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9852 - loss: 0.0164 - val_accuracy: 0.6286 - val_loss: 0.7444
# Epoch 48/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9871 - loss: 0.0144 - val_accuracy: 0.6312 - val_loss: 0.9893

# %%
plot_metrics(history)

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    plt.figure(figsize=(6, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    cm = np.round(cm, 2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
# Validate on test set

predictions = model.predict(X_test)
y_pred = [np.argmax(probas) for probas in predictions]


accuracy = accuracy_score(y_test, y_pred)
print('Test Accuracy = %.2f' % accuracy)

confusion_mtx = confusion_matrix(y_test, y_pred) 
cm = plot_confusion_matrix(confusion_mtx, classes = list(test_labels.items()), normalize=False)
# Out:
#  13/221 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step
# W0000 00:00:1715532936.612243     119 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step
# W0000 00:00:1715532939.541577     116 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Test Accuracy = 0.63

# %%
def evaluate_model(model, X_test, y_test, test_labels):
    # Evaluate on test set
    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
    print('Test Loss:', loss)
    print('Test Accuracy:', accuracy)

    # Confusion matrix
    predictions = model.predict(X_test)
    y_pred = np.argmax(predictions, axis=1)
    confusion_mtx = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
    plot_confusion_matrix(confusion_mtx, classes=list(test_labels.values()), normalize=False)

    # Classification report
    target_names = list(test_labels.values())
    print(classification_report(np.argmax(y_test, axis=1), y_pred, target_names=target_names))

evaluate_model(model, X_test, Y_test, test_labels)
# Out:
# Test Loss: 0.989344596862793
# Test Accuracy: 0.6312438249588013
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#               precision    recall  f1-score   support
#
#        Angry       0.58      0.51      0.54       958
#         Fear       0.51      0.48      0.49      1024
#        Happy       0.86      0.77      0.81      1774
#      Neutral       0.62      0.52      0.57      1233
#          Sad       0.45      0.65      0.53      1247
#      Suprise       0.78      0.79      0.79       831
#
#     accuracy                           0.63      7067
#    macro avg       0.63      0.62      0.62      7067
# weighted avg       0.65      0.63      0.64      7067

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define your batch size
batch_size = 32  # or whatever batch size you want to use

datagen_test = ImageDataGenerator(rescale=1./255)
pred_generator = datagen_test.flow_from_directory(TEST_DIR,
                                                   target_size=(48, 48),
                                                   color_mode="grayscale",
                                                   batch_size=batch_size,
                                                   class_mode="categorical",
                                                   shuffle=False)
# Out:
# Found 7067 images belonging to 6 classes.

# %%
new_predictions = model.predict(X_test)
y_pred = [np.argmax(probas) for probas in new_predictions]
y_pred = [test_labels[k] for k in y_pred]
# Out:
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step

# %%
filenames = pred_generator.filenames
actual_class = [test_labels[h] for h in pred_generator.classes]

# %%
import pandas as pd

pred_result = pd.DataFrame({"Filename":filenames,
                           "Predictions":y_pred,
                           "Actual Values":actual_class})

pred_result.head()
# Out:
#               Filename Predictions Actual Values
# 0    Angry/Angry-1.jpg       Angry         Angry
# 1   Angry/Angry-10.jpg         Sad         Angry
# 2  Angry/Angry-100.jpg       Angry         Angry
# 3  Angry/Angry-101.jpg       Angry         Angry
# 4  Angry/Angry-102.jpg         Sad         Angry

# %%
from random import randint

l = len(filenames)
base_path = TEST_DIR
for i in range(10):  # 10 images
    
    rnd_number = randint(0,l-1)
    filename,pred_class,actual_class = pred_result.loc[rnd_number]
    
    img_path = os.path.join(base_path,filename)
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.title("Predicted Class: {} {} Actual Class: {}".format(pred_class,'\n',actual_class))
    plt.show()
    pass
