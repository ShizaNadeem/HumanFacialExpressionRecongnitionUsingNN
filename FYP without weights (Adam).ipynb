# %% [markdown]
# **Import libraries**

# %%
import numpy as np
import cv2
import os
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import itertools
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.models import Model, Sequential
from keras.optimizers import Adam, RMSprop
from keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

init_notebook_mode(connected=True)

# Ensure reproducibility
np.random.seed(123)
tf.random.set_seed(123)
# Out:
# 2024-05-13 13:07:56.704804: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-13 13:07:56.704959: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-13 13:07:56.811539: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # **Load Data and Plot Samples**

# %%
TRAIN_DIR = ('/kaggle/input/facial-recognition-dataset/Training/Training/')
TEST_DIR = ('/kaggle/input/facial-recognition-dataset/Testing/Testing/')

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

def load_data(dir_path, IMG_SIZE):
    X = []
    y = []
    labels = dict()
    i = 0
    
    for path in tqdm(sorted(os.listdir(dir_path))):
        if not path.startswith('.'):
            labels[i] = path
            for file in os.listdir(os.path.join(dir_path, path)):
                if not file.startswith('.'):
                    img_path = os.path.join(dir_path, path, file)
                    img = cv2.imread(img_path)
                    if img is not None:
                        img = img.astype('float32') / 255
                        resized = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
                        X.append(resized)
                        y.append(i)
                    else:
                        print(f"Error loading image: {img_path}")
            i += 1
    
    return np.array(X), np.array(y), labels

# Usage example:
TRAIN_DIR = ('/kaggle/input/facial-recognition-dataset/Training/Training/')
IMG_SIZE = (48, 48)  # Example image size
X_train, y_train, train_labels = load_data(TRAIN_DIR, IMG_SIZE)
# Out:
# 100%|██████████| 6/6 [03:25<00:00, 34.33s/it]

# %%
train_labels
# Out:
# {0: 'Angry', 1: 'Fear', 2: 'Happy', 3: 'Neutral', 4: 'Sad', 5: 'Suprise'}

# %%
X_test, y_test, test_labels = load_data(TEST_DIR,IMG_SIZE)
# Out:
# 100%|██████████| 6/6 [00:41<00:00,  6.98s/it]

# %%
def plot_samples(X, y, labels_dict, n=50):
   
    for index in range(len(labels_dict)):
        imgs = X[np.argwhere(y == index)][:n]
        j = 10
        i = int(n/j)

        plt.figure(figsize=(10,3))
        c = 1
        for img in imgs:
            plt.subplot(i,j,c)
            plt.imshow(img[0])

            plt.xticks([])
            plt.yticks([])
            c += 1
        plt.suptitle(labels_dict[index])
        plt.show()

# %%
plot_samples(X_train, y_train, train_labels, 10)

# %%
from keras.utils import to_categorical

Y_train = to_categorical(y_train, num_classes=6)
print(Y_train.shape)
# Out:
# (28273, 6)

# %%
Y_test = to_categorical(y_test, num_classes=6)
Y_test.shape
# Out:
# (7067, 6)

# %% [markdown]
# # Model without weights

# %%
from keras.applications.vgg16 import VGG16
base_model = VGG16(
    weights=None,
    include_top=False,
    input_shape=IMG_SIZE + (3,)
)

base_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 48, 48, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 48, 48, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 1, 1, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
NUM_CLASSES = 6

model = Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(1000, activation="relu"))
model.add(Dropout(0.4))
model.add(Dense(NUM_CLASSES, activation="softmax"))

# %%
def deep_model(model, X_train, Y_train, X_val, Y_val, epochs, batch_size):
    # Check input shapes
    print("X_train shape:", X_train.shape)
    print("Y_train shape:", Y_train.shape)
    print("X_val shape:", X_val.shape)
    print("Y_val shape:", Y_val.shape)
    
    # Compile the model
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(learning_rate=1e-4),
        metrics=['accuracy']
    )
    
    # Fit the model
    history = model.fit(
        X_train,
        Y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_val, Y_val),  # Use X_val, Y_val for validation
        verbose=1
    )
    
    return history

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

def plot_metrics(history):
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

# %%
history = deep_model(model, X_train, Y_train, X_test, Y_test, epochs=48, batch_size=32)
# Out:
# X_train shape: (28273, 48, 48, 3)
# Y_train shape: (28273, 6)
# X_val shape: (7067, 48, 48, 3)
# Y_val shape: (7067, 6)
# Epoch 1/48
#   3/884 ━━━━━━━━━━━━━━━━━━━━ 47s 53ms/step - accuracy: 0.1892 - loss: 0.6925
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715606068.754225     118 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1715606068.778497     118 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2332 - loss: 0.4630
# W0000 00:00:1715606107.379692     116 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1715606108.715918     115 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 60s 51ms/step - accuracy: 0.2332 - loss: 0.4630 - val_accuracy: 0.2510 - val_loss: 0.4405
# Epoch 2/48
#   3/884 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.2431 - loss: 0.4480
# W0000 00:00:1715606113.964400     117 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 34s 38ms/step - accuracy: 0.3076 - loss: 0.4224 - val_accuracy: 0.3978 - val_loss: 0.3809
# Epoch 3/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 40ms/step - accuracy: 0.4389 - loss: 0.3625 - val_accuracy: 0.4579 - val_loss: 0.3546
# Epoch 4/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 34s 39ms/step - accuracy: 0.5123 - loss: 0.3272 - val_accuracy: 0.5121 - val_loss: 0.3236
# Epoch 5/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.5599 - loss: 0.3024 - val_accuracy: 0.5421 - val_loss: 0.3101
# Epoch 6/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.6084 - loss: 0.2790 - val_accuracy: 0.5568 - val_loss: 0.3078
# Epoch 7/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 34s 39ms/step - accuracy: 0.6494 - loss: 0.2565 - val_accuracy: 0.5497 - val_loss: 0.3228
# Epoch 8/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.6886 - loss: 0.2351 - val_accuracy: 0.5632 - val_loss: 0.3249
# Epoch 9/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.7281 - loss: 0.2100 - val_accuracy: 0.5632 - val_loss: 0.3304
# Epoch 10/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.7702 - loss: 0.1836 - val_accuracy: 0.5630 - val_loss: 0.3382
# Epoch 11/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.7988 - loss: 0.1633 - val_accuracy: 0.5785 - val_loss: 0.3579
# Epoch 12/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.8313 - loss: 0.1402 - val_accuracy: 0.5786 - val_loss: 0.3942
# Epoch 13/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.8536 - loss: 0.1238 - val_accuracy: 0.5827 - val_loss: 0.3917
# Epoch 14/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.8804 - loss: 0.1041 - val_accuracy: 0.5776 - val_loss: 0.4475
# Epoch 15/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.8918 - loss: 0.0927 - val_accuracy: 0.5819 - val_loss: 0.4588
# Epoch 16/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9083 - loss: 0.0799 - val_accuracy: 0.5775 - val_loss: 0.4499
# Epoch 17/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 40ms/step - accuracy: 0.9211 - loss: 0.0704 - val_accuracy: 0.5872 - val_loss: 0.5013
# Epoch 18/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 40ms/step - accuracy: 0.9325 - loss: 0.0623 - val_accuracy: 0.5879 - val_loss: 0.5131
# Epoch 19/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 40ms/step - accuracy: 0.9447 - loss: 0.0525 - val_accuracy: 0.5855 - val_loss: 0.5135
# Epoch 20/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9491 - loss: 0.0472 - val_accuracy: 0.5817 - val_loss: 0.5262
# Epoch 21/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9528 - loss: 0.0460 - val_accuracy: 0.5792 - val_loss: 0.5284
# Epoch 22/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9612 - loss: 0.0378 - val_accuracy: 0.5864 - val_loss: 0.5220
# Epoch 23/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 40ms/step - accuracy: 0.9612 - loss: 0.0352 - val_accuracy: 0.5952 - val_loss: 0.5644
# Epoch 24/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9648 - loss: 0.0338 - val_accuracy: 0.5916 - val_loss: 0.5700
# Epoch 25/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9677 - loss: 0.0312 - val_accuracy: 0.5848 - val_loss: 0.5672
# Epoch 26/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9729 - loss: 0.0278 - val_accuracy: 0.5925 - val_loss: 0.5933
# Epoch 27/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9715 - loss: 0.0281 - val_accuracy: 0.5872 - val_loss: 0.6015
# Epoch 28/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9716 - loss: 0.0279 - val_accuracy: 0.5891 - val_loss: 0.6281
# Epoch 29/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9755 - loss: 0.0261 - val_accuracy: 0.5732 - val_loss: 0.6007
# Epoch 30/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 41s 39ms/step - accuracy: 0.9779 - loss: 0.0219 - val_accuracy: 0.5847 - val_loss: 0.6266
# Epoch 31/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9794 - loss: 0.0207 - val_accuracy: 0.5828 - val_loss: 0.6066
# Epoch 32/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 41s 39ms/step - accuracy: 0.9771 - loss: 0.0227 - val_accuracy: 0.5882 - val_loss: 0.6581
# Epoch 33/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9809 - loss: 0.0203 - val_accuracy: 0.5988 - val_loss: 0.6059
# Epoch 34/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9791 - loss: 0.0193 - val_accuracy: 0.5845 - val_loss: 0.6482
# Epoch 35/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9808 - loss: 0.0194 - val_accuracy: 0.5901 - val_loss: 0.6057
# Epoch 36/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9829 - loss: 0.0166 - val_accuracy: 0.5916 - val_loss: 0.6340
# Epoch 37/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9823 - loss: 0.0168 - val_accuracy: 0.6012 - val_loss: 0.6347
# Epoch 38/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9859 - loss: 0.0145 - val_accuracy: 0.5769 - val_loss: 0.6923
# Epoch 39/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9807 - loss: 0.0180 - val_accuracy: 0.6028 - val_loss: 0.6160
# Epoch 40/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9859 - loss: 0.0138 - val_accuracy: 0.6068 - val_loss: 0.7633
# Epoch 41/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9843 - loss: 0.0158 - val_accuracy: 0.5937 - val_loss: 0.6729
# Epoch 42/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9838 - loss: 0.0174 - val_accuracy: 0.5847 - val_loss: 0.6666
# Epoch 43/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9851 - loss: 0.0149 - val_accuracy: 0.5987 - val_loss: 0.7700
# Epoch 44/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9856 - loss: 0.0142 - val_accuracy: 0.6020 - val_loss: 0.6522
# Epoch 45/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9876 - loss: 0.0120 - val_accuracy: 0.5949 - val_loss: 0.6641
# Epoch 46/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9863 - loss: 0.0124 - val_accuracy: 0.6024 - val_loss: 0.6576
# Epoch 47/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9876 - loss: 0.0126 - val_accuracy: 0.6056 - val_loss: 0.6195
# Epoch 48/48
# 884/884 ━━━━━━━━━━━━━━━━━━━━ 35s 39ms/step - accuracy: 0.9876 - loss: 0.0124 - val_accuracy: 0.5980 - val_loss: 0.7423

# %%
plot_metrics(history)

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    plt.figure(figsize=(6, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    cm = np.round(cm, 2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
# Validate on test set

predictions = model.predict(X_test)
y_pred = [np.argmax(probas) for probas in predictions]


accuracy = accuracy_score(y_test, y_pred)
print('Test Accuracy = %.2f' % accuracy)

confusion_mtx = confusion_matrix(y_test, y_pred) 
cm = plot_confusion_matrix(confusion_mtx, classes = list(test_labels.items()), normalize=False)
# Out:
#  13/221 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step
# W0000 00:00:1715607784.487901     116 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step
# W0000 00:00:1715607787.452507     117 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Test Accuracy = 0.60

# %%
def evaluate_model(model, X_test, y_test, test_labels):
    # Evaluate on test set
    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
    print('Test Loss:', loss)
    print('Test Accuracy:', accuracy)

    # Confusion matrix
    predictions = model.predict(X_test)
    y_pred = np.argmax(predictions, axis=1)
    confusion_mtx = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
    plot_confusion_matrix(confusion_mtx, classes=list(test_labels.values()), normalize=False)

    # Classification report
    target_names = list(test_labels.values())
    print(classification_report(np.argmax(y_test, axis=1), y_pred, target_names=target_names))

evaluate_model(model, X_test, Y_test, test_labels)
# Out:
# Test Loss: 0.7422563433647156
# Test Accuracy: 0.5979906320571899
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
#               precision    recall  f1-score   support
#
#        Angry       0.51      0.54      0.52       958
#         Fear       0.42      0.46      0.44      1024
#        Happy       0.77      0.84      0.80      1774
#      Neutral       0.55      0.53      0.54      1233
#          Sad       0.49      0.41      0.45      1247
#      Suprise       0.76      0.72      0.74       831
#
#     accuracy                           0.60      7067
#    macro avg       0.58      0.58      0.58      7067
# weighted avg       0.59      0.60      0.59      7067

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define your batch size
batch_size = 32  # or whatever batch size you want to use

datagen_test = ImageDataGenerator(rescale=1./255)
pred_generator = datagen_test.flow_from_directory(TEST_DIR,
                                                   target_size=(48, 48),
                                                   color_mode="grayscale",
                                                   batch_size=batch_size,
                                                   class_mode="categorical",
                                                   shuffle=False)
# Out:
# Found 7067 images belonging to 6 classes.

# %%
new_predictions = model.predict(X_test)
y_pred = [np.argmax(probas) for probas in new_predictions]
y_pred = [test_labels[k] for k in y_pred]
# Out:
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step

# %%
filenames = pred_generator.filenames
actual_class = [test_labels[h] for h in pred_generator.classes]

# %%
import pandas as pd

pred_result = pd.DataFrame({"Filename":filenames,
                           "Predictions":y_pred,
                           "Actual Values":actual_class})

pred_result.head()
# Out:
#               Filename Predictions Actual Values
# 0    Angry/Angry-1.jpg         Sad         Angry
# 1   Angry/Angry-10.jpg     Suprise         Angry
# 2  Angry/Angry-100.jpg         Sad         Angry
# 3  Angry/Angry-101.jpg       Angry         Angry
# 4  Angry/Angry-102.jpg         Sad         Angry

# %%
from random import randint

l = len(filenames)
base_path = TEST_DIR
for i in range(10):  # 10 images
    
    rnd_number = randint(0,l-1)
    filename,pred_class,actual_class = pred_result.loc[rnd_number]
    
    img_path = os.path.join(base_path,filename)
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.title("Predicted Class: {} {} Actual Class: {}".format(pred_class,'\n',actual_class))
    plt.show()
    pass
